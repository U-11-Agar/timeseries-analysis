# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

# %%
B_NIFTY=['HDFCBANK.NS','ICICIBANK.NS','KOTAKBANK.NS','SBIN.NS','AXISBANK.NS','INDUSINDBK.NS','AUBANK.NS','BANDHANBNK.NS','BANKBARODA.NS','FEDERALBNK.NS','IDFCFIRSTB.NS','PNB.NS']

# %%
df=yf.download(tickers=B_NIFTY,start='2020-04-01')
# Out:
# [*********************100%***********************]  12 of 12 completed

# %%
df=df['Adj Close']
df.dropna(inplace=True,axis=0)

# %%
df.head(20)
# Out:
#              AUBANK.NS  AXISBANK.NS  BANDHANBNK.NS  BANKBARODA.NS  \
# Date
# 2020-04-01  240.468185   358.104889     194.241669      49.751923
# 2020-04-03  232.525024   324.955383     180.936768      47.276463
# 2020-04-07  238.994446   388.259003     166.685059      46.742538
# 2020-04-08  239.943634   390.755219     193.095551      46.936691
# 2020-04-09  247.986710   419.511414     191.600616      49.412155
# 2020-04-13  249.660278   418.313263     192.348083      48.392845
# 2020-04-15  250.909210   416.665741     186.169037      47.519154
# 2020-04-16  256.829102   421.907776     197.530518      48.150150
# 2020-04-17  269.668060   478.072266     215.569382      48.732616
# 2020-04-20  282.656891   455.257019     215.270401      49.703384
# 2020-04-21  279.734406   420.010651     194.690155      47.130844
# 2020-04-22  265.771423   430.494720     198.178329      46.888153
# 2020-04-23  252.907486   429.396362     200.370895      47.033772
# 2020-04-24  258.802399   403.336060     197.779678      44.995152
# 2020-04-27  257.878204   426.650543     207.646240      45.383461
# 2020-04-28  256.104736   454.757782     220.353180      45.917385
# 2020-04-29  268.868774   438.432648     233.658066      46.693996
# 2020-04-30  271.891144   444.223816     261.463837      47.761848
# 2020-05-04  258.302826   402.187775     240.136124      44.509769
# 2020-05-05  245.388962   388.408783     235.451996      42.713844
#
#             FEDERALBNK.NS  HDFCBANK.NS  ICICIBANK.NS  IDFCFIRSTB.NS  \
# Date
# 2020-04-01      40.252136   807.322144    308.390961      20.600000
# 2020-04-03      38.887657   791.947266    284.108185      19.650000
# 2020-04-07      41.616619   871.983765    323.208374      20.450001
# 2020-04-08      39.813553   864.977478    316.121796      20.549999
# 2020-04-09      39.911018   900.154602    339.661194      22.049999
# 2020-04-13      39.618629   871.253906    327.718048      22.200001
# 2020-04-15      40.349598   840.066467    324.447327      22.600000
# 2020-04-16      41.129303   856.073730    338.967407      24.150000
# 2020-04-17      44.832890   885.801575    372.219910      26.400000
# 2020-04-20      44.881618   919.421753    358.096252      24.850000
# 2020-04-21      42.250122   896.846130    328.907410      23.700001
# 2020-04-22      42.932362   903.609070    332.971069      23.950001
# 2020-04-23      43.858261   929.250000    349.820312      23.700001
# 2020-04-24      42.006466   912.804749    331.880798      22.200001
# 2020-04-27      43.370949   904.679443    344.815094      22.100000
# 2020-04-28      45.563858   906.333740    356.659149      22.250000
# 2020-04-29      45.320202   950.803772    367.165161      22.000000
# 2020-04-30      47.561848   974.839050    376.779114      21.900000
# 2020-05-04      42.932362   898.159729    335.052399      20.600000
# 2020-05-05      41.860271   886.920593    327.916290      20.650000
#
#             INDUSINDBK.NS  KOTAKBANK.NS     PNB.NS     SBIN.NS
# Date
# 2020-04-01     334.181488   1180.352905  29.415201  178.533707
# 2020-04-03     305.816376   1139.597656  28.642387  167.958542
# 2020-04-07     374.800781   1196.734985  29.028795  178.390152
# 2020-04-08     389.740082   1186.346313  29.463501  175.136246
# 2020-04-09     386.078491   1271.502808  30.332916  179.682144
# 2020-04-13     400.724854   1249.526978  30.284616  175.614761
# 2020-04-15     414.101868   1172.461670  30.043112  174.514191
# 2020-04-16     425.135498   1129.608643  29.994810  180.399902
# 2020-04-17     463.264893   1184.947876  30.719324  184.945801
# 2020-04-20     445.933350   1176.457153  31.733641  184.228027
# 2020-04-21     391.400024   1128.909546  30.043112  176.811050
# 2020-04-22     406.095215   1150.885254  30.043112  180.591324
# 2020-04-23     400.285492   1248.278320  30.139715  178.677246
# 2020-04-24     373.873199   1238.189453  29.173698  172.025909
# 2020-04-27     397.795593   1302.169067  29.705008  173.126495
# 2020-04-28     457.015778   1325.193726  30.188015  176.380386
# 2020-04-29     459.993896   1326.392334  31.202330  181.931168
# 2020-04-30     457.113403   1355.710205  31.202330  182.313980
# 2020-05-04     413.076660   1276.397461  29.125397  171.164597
# 2020-05-05     408.829224   1236.990723  28.207682  163.077698

# %%
df.isnull().any().unique()
# Out:
# array([False])

# %%
df.describe()
# Out:
#         AUBANK.NS  AXISBANK.NS  BANDHANBNK.NS  BANKBARODA.NS  FEDERALBNK.NS  \
# count  804.000000   804.000000     804.000000     804.000000     804.000000
# mean   542.512104   703.547036     290.008383      98.847982      89.839423
# std    135.345105   155.569866      46.382319      45.726456      28.569338
# min    189.911667   324.955383     166.685059      35.433075      36.402355
# 25%    457.469040   635.757263     253.947334      64.774574      70.757992
# 50%    586.657959   732.410126     292.079727      86.204308      86.069126
# 75%    633.473938   797.789337     319.703941     128.187496     114.875002
# max    790.400024   985.849976     421.770538     198.100006     140.300003
#
#        HDFCBANK.NS  ICICIBANK.NS  IDFCFIRSTB.NS  INDUSINDBK.NS  KOTAKBANK.NS  \
# count   804.000000    804.000000     804.000000     804.000000    804.000000
# mean   1394.055539    673.773446      46.036505     916.928982   1742.129592
# std     206.012922    191.590142      12.916625     234.616037    226.197991
# min     791.947266    284.108185      18.850000     305.816376   1112.427612
# 25%    1337.338287    539.448776      35.212500     834.562744   1711.019714
# 50%    1444.176147    706.659363      47.799999     955.604919   1793.245483
# 75%    1539.599762    848.712509      55.799999    1091.958221   1894.025024
# max    1708.210449    954.299988      82.800003    1336.250000   2209.619629
#
#            PNB.NS     SBIN.NS
# count  804.000000  804.000000
# mean    37.817560  407.473796
# std      7.537460  138.548852
# min     25.696039  144.367783
# 25%     32.554756  281.330566
# 50%     36.180107  445.305420
# 75%     40.669292  515.070328
# max     59.136570  613.576660

# %%
df.plot(figsize=(17,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
df_scaled=scaler.fit_transform(df)

# %%
s_df=pd.DataFrame(df_scaled,columns=df.columns)

# %%
s_df.plot(figsize=(17,10))
# Out:
# <AxesSubplot:>

# %%
s_df.plot(kind='density',figsize=(17,10))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
s_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 804 entries, 0 to 803
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   AUBANK.NS      804 non-null    float64
#  1   AXISBANK.NS    804 non-null    float64
#  2   BANDHANBNK.NS  804 non-null    float64
#  3   BANKBARODA.NS  804 non-null    float64
#  4   FEDERALBNK.NS  804 non-null    float64
#  5   HDFCBANK.NS    804 non-null    float64
#  6   ICICIBANK.NS   804 non-null    float64
#  7   IDFCFIRSTB.NS  804 non-null    float64
#  8   INDUSINDBK.NS  804 non-null    float64
#  9   KOTAKBANK.NS   804 non-null    float64
#  10  PNB.NS         804 non-null    float64
#  11  SBIN.NS        804 non-null    float64
# dtypes: float64(12)
# memory usage: 75.5 KB

# %%
s_df
# Out:
#      AUBANK.NS  AXISBANK.NS  BANDHANBNK.NS  BANKBARODA.NS  FEDERALBNK.NS  \
# 0    -2.233047    -2.221877      -2.066010      -1.074359      -1.736762
# 1    -2.291771    -2.435094      -2.353041      -1.128529      -1.784552
# 2    -2.243942    -2.027927      -2.660498      -1.140213      -1.688972
# 3    -2.236925    -2.011871      -2.090735      -1.135964      -1.752124
# 4    -2.177461    -1.826912      -2.122986      -1.081794      -1.748710
# ..         ...          ...            ...            ...            ...
# 799   1.530656     1.688093      -1.044331       2.171911       1.177189
# 800   1.465966     1.691952      -1.109051       2.066874       1.189447
# 801   1.435654     1.639210      -1.170536       2.042803       1.131657
# 802   1.499975     1.653038      -1.153277       2.011073       1.101886
# 803   1.532504     1.734724      -1.121996       2.015449       1.163179
#
#      HDFCBANK.NS  ICICIBANK.NS  IDFCFIRSTB.NS  INDUSINDBK.NS  KOTAKBANK.NS  \
# 0      -2.849815     -1.908292      -1.970510      -2.485381     -2.485108
# 1      -2.924492     -2.035114      -2.044104      -2.606356     -2.665395
# 2      -2.535747     -1.830905      -1.982130      -2.312142     -2.412639
# 3      -2.569778     -1.867916      -1.974383      -2.248427     -2.458595
# 4      -2.398919     -1.744976      -1.858182      -2.264044     -2.081892
# ..           ...           ...            ...            ...           ...
# 799     1.173202      1.310520       2.801506       1.576623      0.457497
# 800     1.212059      1.316004       2.445154       1.517341      0.415693
# 801     1.211573      1.304253       2.456774       1.670878      0.382295
# 802     1.172960      1.324883       2.456774       1.697961      0.357522
# 803     1.284915      1.370059       2.495508       1.701799      0.453736
#
#        PNB.NS   SBIN.NS
# 0   -1.115441 -1.653443
# 1   -1.218034 -1.729818
# 2   -1.166737 -1.654480
# 3   -1.109029 -1.677980
# 4   -0.993611 -1.645149
# ..        ...       ...
# 799  1.906186  1.147430
# 800  1.663723  1.122875
# 801  1.683635  1.062569
# 802  1.657085  1.080264
# 803  1.730099  1.145624
#
# [804 rows x 12 columns]

# %% [markdown]
# portfolio optimization by minimizing MCVaR

# %%
portfolio=pd.DataFrame()
weights=[1]*len(s_df.columns)
weights/=np.sum(weights)
print(dict(zip(df.columns,weights)))

portfolio['bank_nifty']=np.dot(df,weights)
# Out:
# {'AUBANK.NS': 0.08333333333333333, 'AXISBANK.NS': 0.08333333333333333, 'BANDHANBNK.NS': 0.08333333333333333, 'BANKBARODA.NS': 0.08333333333333333, 'FEDERALBNK.NS': 0.08333333333333333, 'HDFCBANK.NS': 0.08333333333333333, 'ICICIBANK.NS': 0.08333333333333333, 'IDFCFIRSTB.NS': 0.08333333333333333, 'INDUSINDBK.NS': 0.08333333333333333, 'KOTAKBANK.NS': 0.08333333333333333, 'PNB.NS': 0.08333333333333333, 'SBIN.NS': 0.08333333333333333}

# %%
import seaborn as sns
fig=plt.figure(figsize=(10,10))
sns.kdeplot(portfolio['bank_nifty'])
plt.show()
sns.histplot(portfolio['bank_nifty'])
# Out:
# <AxesSubplot:xlabel='bank_nifty', ylabel='Count'>

# %%
# !pip install pyportfolioopt
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt.expected_returns import mean_historical_return
from pypfopt.expected_returns import capm_return
from pypfopt.expected_returns import ema_historical_return
from pypfopt.risk_models import CovarianceShrinkage
from pypfopt.discrete_allocation import DiscreteAllocation, get_latest_prices
from pypfopt import HRPOpt
from pypfopt.efficient_frontier import EfficientCVaR

# %% [markdown]
# building portfolio with Mean - variance

# %%
mu = mean_historical_return(df)
# mu = capm_return(df)
# mu= ema_historical_return(df)
S = CovarianceShrinkage(df).ledoit_wolf()


ef = EfficientFrontier(mu, S)
mv_weights = ef.max_sharpe()


print(dict(mv_weights))


ef.portfolio_performance(verbose=True)


latest_prices = get_latest_prices(df)

da = DiscreteAllocation(mv_weights, latest_prices, total_portfolio_value=100000)

allocation, leftover = da.greedy_portfolio()
print("Discrete allocation:", allocation)
print("Funds remaining: ${:.2f}".format(leftover))
# Out:
# {'AUBANK.NS': 0.1376754947902568, 'AXISBANK.NS': 0.0, 'BANDHANBNK.NS': 0.0, 'BANKBARODA.NS': 0.1399241544595825, 'FEDERALBNK.NS': 0.0, 'HDFCBANK.NS': 0.0, 'ICICIBANK.NS': 0.2124730926822867, 'IDFCFIRSTB.NS': 0.2182482089900222, 'INDUSINDBK.NS': 0.1098678327539949, 'KOTAKBANK.NS': 0.0, 'PNB.NS': 0.0, 'SBIN.NS': 0.1818112163238568}
# Expected annual return: 47.3%
# Annual volatility: 29.3%
# Sharpe Ratio: 1.55
# Discrete allocation: {'IDFCFIRSTB.NS': 278, 'ICICIBANK.NS': 23, 'SBIN.NS': 32, 'BANKBARODA.NS': 73, 'AUBANK.NS': 18, 'INDUSINDBK.NS': 8}
# Funds remaining: $637.65

# %%
returns = df.pct_change().dropna()
hrp = HRPOpt(returns)
hrp_weights = hrp.optimize()
hrp.portfolio_performance(verbose=True)
print(dict(hrp_weights))

da_hrp = DiscreteAllocation(hrp_weights, latest_prices, total_portfolio_value=100000)

allocation, leftover = da_hrp.greedy_portfolio()
print("Discrete allocation (HRP):", allocation)
print("Funds remaining (HRP): ${:.2f}".format(leftover))
# Out:
# Expected annual return: 35.5%
# Annual volatility: 25.8%
# Sharpe Ratio: 1.30
# {'AUBANK.NS': 0.08883401927984459, 'AXISBANK.NS': 0.05581748815824059, 'BANDHANBNK.NS': 0.0609927432262163, 'BANKBARODA.NS': 0.03730054137673189, 'FEDERALBNK.NS': 0.09384013357107303, 'HDFCBANK.NS': 0.14957966712888562, 'ICICIBANK.NS': 0.06999943369934422, 'IDFCFIRSTB.NS': 0.09028681907982472, 'INDUSINDBK.NS': 0.052386491379611454, 'KOTAKBANK.NS': 0.1443252828062925, 'PNB.NS': 0.04088754606531478, 'SBIN.NS': 0.11574983422862029}
# Discrete allocation (HRP): {'HDFCBANK.NS': 9, 'KOTAKBANK.NS': 8, 'SBIN.NS': 20, 'FEDERALBNK.NS': 76, 'IDFCFIRSTB.NS': 116, 'AUBANK.NS': 12, 'ICICIBANK.NS': 7, 'BANDHANBNK.NS': 26, 'AXISBANK.NS': 6, 'INDUSINDBK.NS': 4, 'PNB.NS': 80, 'BANKBARODA.NS': 19}
# Funds remaining (HRP): $26.55

# %%
S = df.cov()
ef_cvar = EfficientCVaR(mu, S)
cvar_weights = ef_cvar.min_cvar()

# cleaned_weights = ef_cvar.clean_weights()
print(dict(cvar_weights))

ef_cvar.portfolio_performance(verbose=True)

da_cvar = DiscreteAllocation(cvar_weights, latest_prices, total_portfolio_value=100000)

allocation, leftover = da_cvar.greedy_portfolio()
print("Discrete allocation (CVaR):", allocation)
print("Funds remaining (CVaR): ${:.2f}".format(leftover))
# Out:
# {'AUBANK.NS': 1.5459967e-09, 'AXISBANK.NS': 2.5164142e-09, 'BANDHANBNK.NS': 1.0690226e-09, 'BANKBARODA.NS': 3.720527e-10, 'FEDERALBNK.NS': 9.04805e-11, 'HDFCBANK.NS': 2.101997e-09, 'ICICIBANK.NS': 1.4669264e-09, 'IDFCFIRSTB.NS': -5.025373e-10, 'INDUSINDBK.NS': 0.2385300666825869, 'KOTAKBANK.NS': 0.7614699248180277, 'PNB.NS': -1.3603481e-09, 'SBIN.NS': 1.2037145e-09}
# Expected annual return: 24.3%
# Conditional Value at Risk: -93187.51%
# Discrete allocation (CVaR): {'KOTAKBANK.NS': 41, 'INDUSINDBK.NS': 18, 'SBIN.NS': 1}
# Funds remaining (CVaR): $114.10

# %%
from pypfopt.efficient_frontier import EfficientCDaR
ef_cdar=EfficientCDaR(mu,S)
cdar_weights=ef_cdar.min_cdar()
print(dict(cdar_weights))

ef_cdar.portfolio_performance(verbose=True)

da_cdar = DiscreteAllocation(cdar_weights, latest_prices, total_portfolio_value=100000)

allocation, leftover = da_cdar.greedy_portfolio()
print("Discrete allocation (CDaR):", allocation)
print("Funds remaining (CDaR): ${:.2f}".format(leftover))
# Out:
# {'AUBANK.NS': 0.0052776737760313, 'AXISBANK.NS': 0.0030354550327704, 'BANDHANBNK.NS': 0.3767931651882112, 'BANKBARODA.NS': 0.055058281790518, 'FEDERALBNK.NS': 0.0651901670911219, 'HDFCBANK.NS': 0.0034312034507695, 'ICICIBANK.NS': 0.0037048833449588, 'IDFCFIRSTB.NS': 0.1264119214362, 'INDUSINDBK.NS': 0.0016669301525466, 'KOTAKBANK.NS': 0.0043625147670124, 'PNB.NS': 0.3474467504832074, 'SBIN.NS': 0.0076210534866523}
# Expected annual return: 22.3%
# Conditional Drawdown at Risk: 0.00%
# Discrete allocation (CDaR): {'BANDHANBNK.NS': 158, 'PNB.NS': 683, 'IDFCFIRSTB.NS': 161, 'FEDERALBNK.NS': 53, 'BANKBARODA.NS': 28, 'SBIN.NS': 1, 'AUBANK.NS': 1, 'KOTAKBANK.NS': 1}
# Funds remaining (CDaR): $38.35

# %%
from pypfopt.efficient_frontier import EfficientSemivariance
ef_semivariance=EfficientSemivariance(mu,S)
semivariance_weights=ef_semivariance.min_semivariance()
print(dict(semivariance_weights))

ef_semivariance.portfolio_performance(verbose=True)

da_semivariance = DiscreteAllocation(semivariance_weights, latest_prices, total_portfolio_value=100000)

allocation, leftover = da_semivariance.greedy_portfolio()
print("Discrete allocation (CVAR):", allocation)
print("Funds remaining (CVAR): ${:.2f}".format(leftover))
# Out:
# {'AUBANK.NS': 0.0223708616778397, 'AXISBANK.NS': 0.0153218133095428, 'BANDHANBNK.NS': 0.7136782596184755, 'BANKBARODA.NS': 0.0423945365713753, 'FEDERALBNK.NS': 0.0079366868080606, 'HDFCBANK.NS': 0.0070470735484431, 'ICICIBANK.NS': 0.0009996548557521, 'IDFCFIRSTB.NS': 0.0144400260773384, 'INDUSINDBK.NS': 0.0037822490476567, 'KOTAKBANK.NS': 0.0051320470408805, 'PNB.NS': 0.1028917179907661, 'SBIN.NS': 0.0640050734462684}
# Expected annual return: 14.8%
# Annual semi-deviation: 0.0%
# Sortino Ratio: inf
# Discrete allocation (CVAR): {'BANDHANBNK.NS': 299, 'PNB.NS': 202, 'SBIN.NS': 11, 'BANKBARODA.NS': 22, 'AUBANK.NS': 3, 'AXISBANK.NS': 2, 'IDFCFIRSTB.NS': 18, 'FEDERALBNK.NS': 7, 'HDFCBANK.NS': 1}
# Funds remaining (CVAR): $13.95

# %%
portfolio['MV']=np.dot(df,list(mv_weights.values()))
portfolio['HRP']=np.dot(df,list(hrp_weights.values()))
portfolio['CVaR']=np.dot(df,list(cvar_weights.values()))
portfolio['CDaR']=np.dot(df,list(cdar_weights.values()))
portfolio['SemiVariance']=np.dot(df,list(semivariance_weights.values()))

# %%
portfolio.plot(figsize=(17,10),kind='line')
portfolio.plot(figsize=(17,10),kind='kde')
portfolio.plot(figsize=(17,10),kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
portfolio.describe(include='all')
# Out:
#        bank_nifty          MV         HRP         CVaR        CDaR  \
# count  804.000000  804.000000  804.000000   804.000000  804.000000
# mean   578.580862  416.552262  725.291735  1545.294428  164.043605
# std    107.586635  115.066578  123.083065   221.857339   17.506424
# min    296.858476  160.542553  396.469264   934.827792   94.597776
# 25%    553.648779  347.511253  703.016457  1524.944081  155.982005
# 50%    604.704930  438.375511  756.008246  1601.681925  165.362368
# 75%    651.196108  504.347595  808.421297  1697.612633  175.239425
# max    736.234226  599.768171  895.540566  1952.869256  207.609334
#
#        SemiVariance
# count    804.000000
# mean     288.334969
# std       33.182002
# min      161.294089
# 25%      272.715983
# 50%      290.135478
# 75%      310.391404
# max      368.385985

# %%
from scipy import stats

# %%
print(stats.describe(portfolio))
# Out:
# DescribeResult(nobs=804, minmax=(array([296.85847553, 160.54255297, 396.46926381, 934.82779176,
#         94.59777564, 161.29408911]), array([ 736.23422559,  599.76817091,  895.54056586, 1952.86925584,
#         207.60933353,  368.38598496])), mean=array([ 578.58086233,  416.55226175,  725.29173517, 1545.29442771,
#         164.0436047 ,  288.33496925]), variance=array([11574.8840005 , 13240.3173353 , 15149.44094075, 49220.67864891,
#          306.47487228,  1101.04525304]), skewness=array([-0.98622203, -0.61254582, -1.10229588, -1.18407055, -0.97746121,
#        -0.83467274]), kurtosis=array([ 0.01612229, -0.62495088,  0.17905432,  0.38644946,  2.17283316,
#         1.57502515]))
