# %% [markdown]
# <a href="https://colab.research.google.com/github/U-11-Agar/timeseries-notebook/blob/main/lstm_andanient%402.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance
import yfinance as yf
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install yfinance
import yfinance as yf
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='darkgrid', context='talk', palette='rainbow')

# %%
# !pip install yfinance
import yfinance as yf
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='darkgrid', context='talk', palette='rainbow')symbol=['ADANIENT.NS']
df=yf.download('ADANIENT.NS',start="2016-01-01")
df.head(20)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2016-01-01  45.553741  49.422543  44.872616  49.095600  47.614208  10963906
# 2016-01-04  48.768658  50.158157  45.907928  46.371094  44.971909   9408965
# 2016-01-05  46.670792  48.823151  45.880684  48.278248  46.821514   9801814
# 2016-01-06  47.951309  48.468964  46.480076  46.997730  45.579643   7093448
# 2016-01-07  46.262115  46.262115  42.502296  43.564854  42.250347   8919023
# 2016-01-08  44.681900  45.226803  43.946285  44.681900  43.333683   6409374
# 2016-01-11  44.136997  45.717213  42.992706  44.872616  43.518646   7610929
# 2016-01-12  44.872616  45.635475  43.319649  44.028019  42.699539   7187524
# 2016-01-13  44.572922  46.643543  42.066376  44.055264  42.725960  14813664
# 2016-01-14  43.019951  44.136997  42.148109  42.393314  41.114151   8517248
# ...

# %%
# !pip install yfinance
import yfinance as yf
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='darkgrid', context='talk', palette='rainbow')symbol=['ADANIENT.NS']
df=yf.download('ADANIENT.NS',start="2016-01-01")
df.head(20)
df.loc[(df == 0).any(axis=1),'Volume']=df['Volume'].mean()

# %%
# first cheak the data clean hai ki nhi     then my model will be able to predict the open and close for a the next day 
# the variable input to the lstm will be the percentage changes in open and close the std dev for that and the volume pct change

# %%
# !pip install yfinance
import yfinance as yf
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='darkgrid', context='talk', palette='rainbow')symbol=['ADANIENT.NS']
df=yf.download('ADANIENT.NS',start="2016-01-01")
df.head(20)
df.loc[(df == 0).any(axis=1),'Volume']=df['Volume'].mean()
df[(df == 0).any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
# !pip install yfinance
import yfinance as yf
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='darkgrid', context='talk', palette='rainbow')symbol=['ADANIENT.NS']
df=yf.download('ADANIENT.NS',start="2016-01-01")
df.head(20)
df.loc[(df == 0).any(axis=1),'Volume']=df['Volume'].mean()
df[(df == 0).any(axis=1)]
data=df
data.info()
# no empty or missing data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1793 entries, 2016-01-01 to 2023-04-03
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1793 non-null   float64
#  1   High       1793 non-null   float64
#  2   Low        1793 non-null   float64
#  3   Close      1793 non-null   float64
#  4   Adj Close  1793 non-null   float64
#  5   Volume     1793 non-null   float64
# dtypes: float64(6)
# memory usage: 98.1 KB

# %%
df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2016-01-01    45.553741    49.422543    44.872616    49.095600    47.614208
# 2016-01-04    48.768658    50.158157    45.907928    46.371094    44.971909
# 2016-01-05    46.670792    48.823151    45.880684    48.278248    46.821514
# 2016-01-06    47.951309    48.468964    46.480076    46.997730    45.579643
# 2016-01-07    46.262115    46.262115    42.502296    43.564854    42.250347
# ...                 ...          ...          ...          ...          ...
# 2023-03-27  1740.650024  1757.400024  1682.000000  1723.050049  1723.050049
# 2023-03-28  1727.949951  1733.000000  1573.000000  1600.849976  1600.849976
# 2023-03-29  1602.949951  1756.000000  1591.099976  1740.400024  1740.400024
# 2023-03-31  1788.000000  1825.000000  1740.000000  1750.449951  1750.449951
# 2023-04-03  1750.449951  1754.949951  1695.500000  1717.449951  1717.449951
#
#                 Volume
# Date
# ...

# %%
# !pip install yfinance
import yfinance as yf
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='darkgrid', context='talk', palette='rainbow')symbol=['ADANIENT.NS']
df=yf.download('ADANIENT.NS',start="2016-01-01")
df.head(20)
df.loc[(df == 0).any(axis=1),'Volume']=df['Volume'].mean()
df[(df == 0).any(axis=1)]
fig,ax=plt.subplots(3,2,figsize=(22,27))
ax[0,0].plot(df['Volume'])
ax[0,1].plot(df['Open'])
ax[1,0].plot(df['Close'])
ax[1,1].plot(df['High'])
ax[2,0].plot(df['Low'])
ax[2,1].plot(df['Adj Close'])
plt.show()

# %%
# !pip install yfinance
import yfinance as yf
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='darkgrid', context='talk', palette='rainbow')symbol=['ADANIENT.NS']
df=yf.download('ADANIENT.NS',start="2016-01-01")
df.head(20)
df.loc[(df == 0).any(axis=1),'Volume']=df['Volume'].mean()
df[(df == 0).any(axis=1)]
fig,ax=plt.subplots(3,2,figsize=(22,27))
ax[0,0].plot(df['Volume'])
ax[0,1].plot(df['Open'])
ax[1,0].plot(df['Close'])
ax[1,1].plot(df['High'])
ax[2,0].plot(df['Low'])
ax[2,1].plot(df['Adj Close'])
plt.show()
data_vol=data['Volume']

# %%
# !pip install yfinance
import yfinance as yf
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='darkgrid', context='talk', palette='rainbow')symbol=['ADANIENT.NS']
df=yf.download('ADANIENT.NS',start="2016-01-01")
df.head(20)
df.loc[(df == 0).any(axis=1),'Volume']=df['Volume'].mean()
df[(df == 0).any(axis=1)]
fig,ax=plt.subplots(3,2,figsize=(22,27))
ax[0,0].plot(df['Volume'])
ax[0,1].plot(df['Open'])
ax[1,0].plot(df['Close'])
ax[1,1].plot(df['High'])
ax[2,0].plot(df['Low'])
ax[2,1].plot(df['Adj Close'])
plt.show()
data_vol=data['Volume']
fig=plt.figure(figsize=(12,7))
data_vol.tail(252).plot()
plt.show()

# %%
# !pip install yfinance
import yfinance as yf
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='darkgrid', context='talk', palette='rainbow')symbol=['ADANIENT.NS']
df=yf.download('ADANIENT.NS',start="2016-01-01")
df.head(20)
df.loc[(df == 0).any(axis=1),'Volume']=df['Volume'].mean()
df[(df == 0).any(axis=1)]
fig,ax=plt.subplots(3,2,figsize=(22,27))
ax[0,0].plot(df['Volume'])
ax[0,1].plot(df['Open'])
ax[1,0].plot(df['Close'])
ax[1,1].plot(df['High'])
ax[2,0].plot(df['Low'])
ax[2,1].plot(df['Adj Close'])
plt.show()
data_vol=data['Volume']
fig=plt.figure(figsize=(12,7))
data_vol.tail(252).plot()
plt.show()
data_model=pd.DataFrame()
data_model['pct_change_vol']=data_vol.pct_change()
#the reseon to chose this as a variable to input my lstm as change in volume of a stock can show how people are responding to that campany
data_model
# Out:
#             pct_change_vol
# Date
# 2016-01-01             NaN
# 2016-01-04       -0.141824
# 2016-01-05        0.041753
# 2016-01-06       -0.276313
# 2016-01-07        0.257361
# ...                    ...
# 2023-03-27       -0.183406
# 2023-03-28        0.611872
# 2023-03-29        0.145837
# 2023-03-31       -0.475688
# 2023-04-03       -0.295806
#
# [1793 rows x 1 columns]

# %%
data_model['Close']=data['Close']
data_model['Open']=data['Open']
data_model['pct_change_open']=data['Open'].pct_change()
data_model['pct_change_close']=data['Close'].pct_change()

# %%
data_model
# Out:
#             pct_change_vol        Close         Open  pct_change_open  \
# Date
# 2016-01-01             NaN    49.095600    45.553741              NaN
# 2016-01-04       -0.141824    46.371094    48.768658         0.070574
# 2016-01-05        0.041753    48.278248    46.670792        -0.043017
# 2016-01-06       -0.276313    46.997730    47.951309         0.027437
# 2016-01-07        0.257361    43.564854    46.262115        -0.035227
# ...                    ...          ...          ...              ...
# 2023-03-27       -0.183406  1723.050049  1740.650024        -0.030818
# 2023-03-28        0.611872  1600.849976  1727.949951        -0.007296
# 2023-03-29        0.145837  1740.400024  1602.949951        -0.072340
# 2023-03-31       -0.475688  1750.449951  1788.000000         0.115443
# 2023-04-03       -0.295806  1717.449951  1750.449951        -0.021001
#
#             pct_change_close
# Date
# 2016-01-01               NaN
# 2016-01-04         -0.055494
# ...

# %%
# data_model.info()
data.head(10)
data_model['HO']=data['High']-data['Open']
data_model['HC']=data['High']-data['Close']
data_model['CL']=data['Close']-data['Low']
data_model['OL']=data['Open']-data['Low']
data_model['HL']=data['High']-data['Low']
data_model['OC']=data['Open']-data['Close']
data_model
# Out:
#             pct_change_vol        Close         Open  pct_change_open  \
# Date
# 2016-01-01             NaN    49.095600    45.553741              NaN
# 2016-01-04       -0.141824    46.371094    48.768658         0.070574
# 2016-01-05        0.041753    48.278248    46.670792        -0.043017
# 2016-01-06       -0.276313    46.997730    47.951309         0.027437
# 2016-01-07        0.257361    43.564854    46.262115        -0.035227
# ...                    ...          ...          ...              ...
# 2023-03-27       -0.183406  1723.050049  1740.650024        -0.030818
# 2023-03-28        0.611872  1600.849976  1727.949951        -0.007296
# 2023-03-29        0.145837  1740.400024  1602.949951        -0.072340
# 2023-03-31       -0.475688  1750.449951  1788.000000         0.115443
# 2023-04-03       -0.295806  1717.449951  1750.449951        -0.021001
#
#             pct_change_close          HO          HC          CL          OL  \
# Date
# ...

# %%
# fig=plt.figure(figsize=(12,7))
# data['Close'].plot()
# plt.show()
data_model.dropna(inplace=True,axis=0)
data_model
# Out:
#             pct_change_vol        Close         Open  pct_change_open  \
# Date
# 2016-01-04       -0.141824    46.371094    48.768658         0.070574
# 2016-01-05        0.041753    48.278248    46.670792        -0.043017
# 2016-01-06       -0.276313    46.997730    47.951309         0.027437
# 2016-01-07        0.257361    43.564854    46.262115        -0.035227
# 2016-01-08       -0.281382    44.681900    44.681900        -0.034158
# ...                    ...          ...          ...              ...
# 2023-03-27       -0.183406  1723.050049  1740.650024        -0.030818
# 2023-03-28        0.611872  1600.849976  1727.949951        -0.007296
# 2023-03-29        0.145837  1740.400024  1602.949951        -0.072340
# 2023-03-31       -0.475688  1750.449951  1788.000000         0.115443
# 2023-04-03       -0.295806  1717.449951  1750.449951        -0.021001
#
#             pct_change_close          HO          HC          CL          OL  \
# Date
# ...

# %%
y=pd.DataFrame()
y['Open']=data['Open']
y['Close']=data['Close']
y
# Out:
#                    Open        Close
# Date
# 2016-01-01    45.553741    49.095600
# 2016-01-04    48.768658    46.371094
# 2016-01-05    46.670792    48.278248
# 2016-01-06    47.951309    46.997730
# 2016-01-07    46.262115    43.564854
# ...                 ...          ...
# 2023-03-27  1740.650024  1723.050049
# 2023-03-28  1727.949951  1600.849976
# 2023-03-29  1602.949951  1740.400024
# 2023-03-31  1788.000000  1750.449951
# 2023-04-03  1750.449951  1717.449951
#
# [1793 rows x 2 columns]

# %%
# data_model.dropna(inplace=True,axis=0)
# data_model.columns.shape[0]
# y=[]
# y.append(data_model.iloc[1,1:3])
y_data=pd.DataFrame()
y_data['Open']=data_model['Open']
y_data['Close']=data_model['Close']

# %%
print(y_data.iloc[42,:])
# Out:
# Open     34.328777
# Close    34.056328
# Name: 2016-03-03 00:00:00, dtype: float64

# %%
x=[]
x.append(data_model.iloc[0:42,:])
print(type(x))
# Out:
# <class 'list'>

# %%
data_model
n_steps=21
n_features=data_model.columns.shape[0]
X = []
y = []
for i in np.arange(n_steps, len(data_model)):
    X.append(data_model.iloc[i-n_steps:i, :])
    y.append(y_data.iloc[i,:])
X, y = np.array(X), np.array(y)
X = np.reshape(X, (X.shape[0], n_steps, n_features))
print(X.shape)
print(y.shape)
# Out:
# (1771, 21, 11)
# (1771, 2)

# %%
# from keras.models import Sequential
# from keras.layers import LSTM, Dense, Bidirectional

# model = Sequential()

# # First LSTM layer with 64 units
# model.add(Bidirectional(LSTM(units=32, return_sequences=True, input_shape=(n_steps, n_features),use_bias=True)))
# model.add
# # Second LSTM layer with 64 units
# model.add(Bidirectional(LSTM(units=64, return_sequences=True,use_bias=True)))

# # Third LSTM layer with 2 units
# model.add(Bidirectional(LSTM(units=32,use_bias=True)))

# # Output layer with 1 dense unit and sigmoid activation for binary classification
# model.add(Dense(units=2, activation='linear'))

# # Compile the model with binary cross-entropy loss and Adam optimizer
# model.compile(loss='huber', optimizer='adam', metrics=['accuracy','mean squared error','mean absolute error','R-squared', 'precision', 'recall', 'f1-score', 'AUC'])
# # model.summary()

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Bidirectional, LeakyReLU

model = Sequential()

# First LSTM layer with 32 units and LeakyReLU activation function
model.add(Bidirectional(LSTM(units=200, return_sequences=True, input_shape=(n_steps, n_features), use_bias=True)))
model.add(LeakyReLU(alpha=0.01))

# Second LSTM layer with 64 units and LeakyReLU activation function
model.add(Bidirectional(LSTM(units=100, return_sequences=True, use_bias=True)))
model.add(LeakyReLU(alpha=0.01))

# Third LSTM layer with 32 units
model.add(Bidirectional(LSTM(units=50, use_bias=True)))

# Output layer with 2 dense units and linear activation function for regression
model.add(Dense(units=2, activation='linear'))

# Compile the model with mean squared error loss and Adadelta optimizer
model.compile(loss='huber', optimizer='Adadelta', metrics=['accuracy','mse','mae'])
# model.build()
# Print the model summary
# model.summary()

# %%
model

# %%
history = model.fit(X, y, epochs=100, batch_size=10)
# history = model.fit(X, y, epochs=100, batch_size=12, validation_data=(X, y))
# Out:
# Epoch 1/100
# 178/178 [==============================] - 41s 165ms/step - loss: 722.3539 - accuracy: 0.4941 - mse: 1578151.3750 - mae: 722.8541
# Epoch 2/100
# 178/178 [==============================] - 20s 112ms/step - loss: 722.1879 - accuracy: 0.4941 - mse: 1577910.6250 - mae: 722.6879
# Epoch 3/100
# 178/178 [==============================] - 19s 104ms/step - loss: 721.9611 - accuracy: 0.4941 - mse: 1577590.8750 - mae: 722.4611
# Epoch 4/100
# 178/178 [==============================] - 19s 109ms/step - loss: 721.6643 - accuracy: 0.4941 - mse: 1577169.5000 - mae: 722.1643
# Epoch 5/100
# 178/178 [==============================] - 19s 109ms/step - loss: 721.2694 - accuracy: 0.4941 - mse: 1576618.7500 - mae: 721.7694
# Epoch 6/100
# 178/178 [==============================] - 20s 110ms/step - loss: 720.7604 - accuracy: 0.4941 - mse: 1575899.1250 - mae: 721.2604
# Epoch 7/100
# ...

# %%
y_predit=model.predict(x)
# Out:
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=(<tf.Tensor 'IteratorGetNext:0' shape=(None, 11) dtype=float64>,). Consider rewriting this model with the Functional API.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-37ba0e09a9a8> in <cell line: 1>()
# ----> 1 y_predit=model.predict(x)
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in tf__predict_function(iterator)
#      13                 try:
# ...

# %%
fig=plt.figure(figsize=(12,7))
plt.plot(y)
plt.plot(y_predit)
plt.show()

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, input_shape=(n_steps, n_features)))
model.add(LSTM(64))
model.add(Dense(2))

model.compile(optimizer='adam', loss='mse')

# %%
# data_model.iloc[data_model=np.inf]
# print(data_model.iloc[42-n_steps:42, :])
# print(y)

# %%
# fig=plt.figure(figsize=(12,9))
# sns.scatterplot(x=data_model.index,y=y['Close'])
# plt.show()
y

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense 

# # Define the LSTM model
# model = Sequential()

# # Add the input layer
# model.add(LSTM(11, input_shape=(42, 11)))

# # Add the hidden layer

# # Add the output layer
# model.add(Dense(2))

# # Compile the model
# model.compile(loss='mse', optimizer='adam')

# # Print the model summary
# model.fit(X,y,epochs=50)
# y_predict=model.predict(X)

# %%
# Define the number of time steps and features
timesteps = 60
features = 1

# Convert the data into the right format
def create_sequences(data):
    x = []
    y = []
    for i in range(len(data) - timesteps):
        x.append(data[i:i+timesteps])
        y.append(data[i+timesteps])
    x = np.array(x)
    y = np.array(y)
    return x, y

train_x, train_y = create_sequences(train_data)
test_x, test_y = create_sequences(test_data)

train_x = np.reshape(train_x, (train_x.shape[0], timesteps, features))
test_x = np.reshape(test_x, (test_x.shape[0], timesteps, features))

# %%
y_predict

# %%
import numpy as np

# Generate a sample dataframe with 11 columns and 100 rows
data_ = np.random.rand(100, 11)

# Define the number of timesteps and features
n_steps = 42
n_features = 11

# Reshape the data into a 3D array
X = []
y = []
for i in range(n_steps, len(data_)):
    X.append(data_[i-n_steps:i, :])
    y.append(data_[i, :2])
X, y = np.array(X), np.array(y)
X = np.reshape(X, (X.shape[0], X.shape[1], n_features))
print(X.shape)
print(y.shape)
# Define the model architecture
model = Sequential()
model.add(LSTM(units=3, input_shape=(n_steps, n_features)))
model.add(Dense(units=2))

# # Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# # Train the model
model.fit(X, y, epochs=50, batch_size=16)

# %%
data_model.info()

# %%
import requests
import time

api_key = 'your_api_key_here'
symbol = 'EURUSD' # example currency pair

while True:
    url = f'https://www.alphavantage.co/query?function=FX_INTRADAY&from_symbol={symbol[:3]}&to_symbol={symbol[3:]}&interval=1min&apikey={api_key}'
    response = requests.get(url)
    data = response.json()['Time Series FX (1min)']
    for timestamp in data:
        print(f'Timestamp: {timestamp}, Open: {data[timestamp]["1. open"]}, High: {data[timestamp]["2. high"]}, Low: {data[timestamp]["3. low"]}, Close: {data[timestamp]["4. close"]}')
    time.sleep(60)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-7ab9a2b51fd5> in <cell line: 8>()
#       8     url = f'https://www.alphavantage.co/query?function=FX_INTRADAY&from_symbol={symbol[:3]}&to_symbol={symbol[3:]}&interval=1min&apikey={api_key}'
#       9     response = requests.get(url)
# ---> 10     data = response.json()['Time Series FX (1min)']
#      11     for timestamp in data:
#      12         print(f'Timestamp: {timestamp}, Open: {data[timestamp]["1. open"]}, High: {data[timestamp]["2. high"]}, Low: {data[timestamp]["3. low"]}, Close: {data[timestamp]["4. close"]}')
#
# KeyError: 'Time Series FX (1min)'

# %%
# !pip install yfinance
import yfinance as yf
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='darkgrid', context='talk', palette='rainbow')

# Define the symbol for the stock to trade
symbol = 'ADANIENT.NS'

# Download historical stock prices for the given symbol
df = yf.download(symbol, start="2016-01-01")

# Replace zero volume values with the mean volume
df.loc[(df == 0).any(axis=1),'Volume'] = df['Volume'].mean()

# Define the number of time steps and features for the LSTM model
n_steps = 21
n_features = 8

# Define the trading signals dataframe
trading_signals = pd.DataFrame(columns=['signal', 'price'])

# Define the initial trading signal as 'Hold'
trading_signals.loc[df.index[0], 'signal'] = 'Hold'
trading_signals.loc[df.index[0], 'price'] = df['Close'][0]

# Define the trading strategy function
def trading_strategy(model, data):
    X = []
    for i in np.arange(n_steps, len(data)):
        X.append(data.iloc[i-n_steps:i, :])
    X = np.array(X)
    X = np.reshape(X, (X.shape[0], n_steps, n_features))
    y_pred = model.predict(X)
    return y_pred

# Define the LSTM model architecture
from keras.models import Sequential
from keras.layers import LSTM, Dense, Bidirectional, LeakyReLU

model = Sequential()
model.add(Bidirectional(LSTM(units=200, return_sequences=True, input_shape=(n_steps, n_features), use_bias=True)))
model.add(LeakyReLU(alpha=0.01))
model.add(Bidirectional(LSTM(units=100, return_sequences=True, use_bias=True)))
model.add(LeakyReLU(alpha=0.01))
model.add(Bidirectional(LSTM(units=50, use_bias=True)))
model.add(Dense(units=2, activation='linear'))
model.compile(loss='huber', optimizer='Adadelta', metrics=['accuracy','mse','mae'])

# Train the LSTM model
X_train = df[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'pct_change_open', 'pct_change_close']]
y_train = df[['Open', 'Close']]
X_train.dropna(inplace=True,axis=0)
y_train.dropna(inplace=True,axis=0)
history = model.fit(X_train, y_train, epochs=100, batch_size=10)

# Use the LSTM model to generate trading signals
y_pred = trading_strategy(model, X_train)

# Define the trading rules based on the predicted values
for i in range(len(df)-n_steps):
    if y_pred[i, 1] > df['Close'][i+n_steps]:
        trading_signals.loc[df.index[i+n_steps], 'signal'] = 'Buy'
        trading_signals.loc[df.index[i+n_steps], 'price'] = df['Close'][i+n_steps]
    elif y_pred[i, 1] < df['Close'][i+n_steps]:
        trading_signals.loc[df.index[i+n_steps], 'signal'] = 'Sell'
        trading_signals.loc[df.index[i+n_steps], 'price'] = df['Close'][i+n_steps]
    else:
        trading_signals.loc[df.index[i+n_steps], 'signal'] = 'Hold'
        trading_signals.loc

# %%
import pandas as pd
import numpy as np

def calculate_moving_average(dataframe, window=20):
    """
    This function calculates the moving average of a given DataFrame.

    :param dataframe: pandas DataFrame object containing the stock data
    :param window: integer representing the window size for the moving average calculation (default = 20)
    :return: pandas DataFrame object containing the moving average values
    """
    ma = dataframe['Close'].rolling(window=window).mean()
    return pd.DataFrame({'MA': ma})

def calculate_relative_strength_index(dataframe, window=14):
    """
    This function calculates the relative strength index (RSI) of a given DataFrame.

    :param dataframe: pandas DataFrame object containing the stock data
    :param window: integer representing the window size for the RSI calculation (default = 14)
    :return: pandas DataFrame object containing the RSI values
    """
    delta = dataframe['Close'].diff()
    up = delta.where(delta > 0, 0)
    down = -delta.where(delta < 0, 0)
    ema_up = up.ewm(com=window-1, adjust=False).mean()
    ema_down = down.ewm(com=window-1, adjust=False).mean()
    rs = ema_up / ema_down
    rsi = 100 - (100 / (1 + rs))
    return pd.DataFrame({'RSI': rsi})

def calculate_bollinger_bands(dataframe, window=20):
    """
    This function calculates the Bollinger Bands of a given DataFrame.

    :param dataframe: pandas DataFrame object containing the stock data
    :param window: integer representing the window size for the Bollinger Bands calculation (default = 20)
    :return: pandas DataFrame object containing the Bollinger Bands values
    """
    ma = dataframe['Close'].rolling(window=window).mean()
    std = dataframe['Close'].rolling(window=window).std()
    upper_band = ma + (2 * std)
    lower_band = ma - (2 * std)
    return pd.DataFrame({'Upper Band': upper_band, 'Lower Band': lower_band})

def calculate_stochastic_oscillator(dataframe, window=14):
    """
    This function calculates the stochastic oscillator of a given DataFrame.

    :param dataframe: pandas DataFrame object containing the stock data
    :param window: integer representing the window size for the stochastic oscillator calculation (default = 14)
    :return: pandas DataFrame object containing the stochastic oscillator values
    """
    low = dataframe['Low'].rolling(window=window).min()
    high = dataframe['High'].rolling(window=window).max()
    k = 100 * ((dataframe['Close'] - low) / (high - low))
    d = k.rolling(window=3).mean()
    return pd.DataFrame({'%K': k, '%D': d})

# Example usage
stock_data = pd.read_csv('stock_data.csv')
stock_data['Date'] = pd.to_datetime(stock_data['Date'])
stock_data.set_index('Date', inplace=True)

ma_df = calculate_moving_average(stock_data)
rsi_df = calculate_relative_strength_index(stock_data)
bb_df = calculate_bollinger_bands(stock_data)
stochastic_df = calculate_stochastic_oscillator(stock_data)

# Combine all the indicators into one DataFrame
indicators_df = pd.concat([ma_df, rsi_df, bb_df, stochastic_df], axis=1)

print(indicators_df.head())

# %%
import pandas as pd

# %%
a=pd.DataFrame({'s':[0,2,3],'d':[2,3,4]})
b=pd.DataFrame({'a':[1,0,3],'q':[2,3,4]})
a[b.columns]=b

# %%
a
# Out:
#    s  d  a  q
# 0  0  2  1  2
# 1  2  3  0  3
# 2  3  4  3  4

# %%
a.columns.shape[0]
# Out:
# 4

# %%
a.loc[(a == 0).any(axis=1),:]=a.loc[((a == 0).any(axis=1))-1,:]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-542dcfd9b1c0> in <cell line: 1>()
# ----> 1 a.loc[(a == 0).any(axis=1),:]=a.loc[((a == 0).any(axis=1))-1,:]
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     959             if self._is_scalar_access(key):
#     960                 return self.obj._get_value(*key, takeable=self._takeable)
# --> 961             return self._getitem_tuple(key)
#     962         else:
#     963             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1147             return self._multi_take(tup)
#    1148
# -> 1149         return self._getitem_tuple_same_dim(tup)
#    1150
#    1151     def _get_label(self, label, axis: int):
#
# ...

# %%
data_model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f0542aa598d0> in <cell line: 1>()
# ----> 1 data_model
#
# NameError: name 'data_model' is not defined

# %%
# !pip install yfinance
import yfinance as yf
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dense, Bidirectional, LeakyReLU,Dropout,BatchNormalization
from keras.losses import mean_squared_error
from keras.metrics import RootMeanSquaredError
# Define the LSTM model architecture

# Define the symbol for the stock to trade
symbol = 'ADANIENT.NS'

# Download historical stock prices for the given symbol
df = yf.download(symbol, start="2020-01-01")
df.dropna(inplace=True, axis=0)
# df.set_index('Date', inplace=True)
# Replace zero volume values with the mean volume
df.loc[(df == 0).any(axis=1), 'Volume'] = df['Volume'].mean()
df.loc[(df == 0).any(axis=1), 'Close'] = df['Close'].mean()
df.loc[(df == 0).any(axis=1), 'Open'] = df['Open'].mean()


# Define the trading signals dataframe
trading_signals = pd.DataFrame(columns=['signal', 'price'])

# Define the initial trading signal as 'Hold'
trading_signals.loc[df.index[0], 'signal'] = 'Hold'
trading_signals.loc[df.index[0], 'price'] = df['Close'][0]


def data_reshape(x_train, y_train, n_steps, n_features, X, y):
    # X = []
    # for i in np.arange(n_steps, len(data)):
    #     X.append(data.iloc[i-n_steps:i, :])
    # X = np.array(X)
    # X = np.reshape(X, (X.shape[0], n_steps, n_features))
    for i in np.arange(n_steps, len(x_train)):
        X.append(x_train.iloc[i-n_steps:i, :])
        y.append(y_train.iloc[i, :])
    X, y = np.array(X), np.array(y)
    X = np.reshape(X, (X.shape[0], n_steps, n_features))
    return X, y

# Define the trading strategy function


def trading_strategy(model, X,y_pred):
    y_pred = model.predict(X)
    return y_pred


def lstm_model(model,n_steps,n_features):
  model.add(LSTM(units=120, return_sequences=True, input_shape=(n_steps, n_features), use_bias=True,activation='linear'))
  model.add(Dropout(0.05))
  model.add(BatchNormalization())
  model.add(LSTM(units=240, use_bias=True,return_sequences=True,activation='linear'))
  model.add(Dropout(0.05))
  model.add(BatchNormalization())
  model.add(LSTM(units=240, use_bias=True,return_sequences=True,activation='linear'))
  model.add(Dropout(0.05))
  model.add(BatchNormalization())
  model.add(LSTM(units=120, return_sequences=False, use_bias=True,activation='linear'))
  model.add(Dropout(0.05))
  model.add(BatchNormalization())
  model.add(Dense(units=1, activation='linear'))
  model.compile(optimizer='adam', loss=mean_squared_error, metrics=[RootMeanSquaredError()])
  # model.compile(optimizer='adam', loss=mean_squared_error)
  return model


def create_data_model(dataframe, data_model):
    data_model['Close'] = dataframe['Close']
    data_model['Open'] = dataframe['Open']
    data_model['pct_change_open'] = dataframe['Open'].pct_change()
    data_model['pct_change_close'] = dataframe['Close'].pct_change()
    data_model['HO'] = dataframe['High']-dataframe['Open']
    data_model['HC'] = dataframe['High']-dataframe['Close']
    data_model['CL'] = dataframe['Close']-dataframe['Low']
    data_model['OL'] = dataframe['Open']-dataframe['Low']
    data_model['HL'] = dataframe['High']-dataframe['Low']
    data_model['OC'] = dataframe['Open']-dataframe['Close']
    data_model['pct_change_vol'] = dataframe['Volume'].pct_change()
    data_model['Volume'] = (dataframe['Volume']-min(dataframe['Volume']))/max(dataframe['Volume'])
    # Example usage
    # stock_data = pd.read_csv('stock_data.csv')
    # stock_data['Date'] = pd.to_datetime(dataframe['Date'])
    ma_df = calculate_moving_average(dataframe)
    rsi_df = calculate_relative_strength_index(dataframe)
    bb_df = calculate_bollinger_bands(dataframe)
    stochastic_df = calculate_stochastic_oscillator(dataframe)
    # Combine all the indicators into one DataFrame
    indicators_df = pd.concat([ma_df, rsi_df, bb_df, stochastic_df], axis=1)
    data_model[indicators_df.columns] = indicators_df
    data_model.dropna(inplace=True, axis=0)
    return data_model
    # print(indicators_df.head())
# the reseon to chose this as a variable to input my lstm as change in volume of a stock can show how people are responding to that campany


def calculate_moving_average(dataframe, window=20):
    ma = dataframe['Close'].rolling(window=window).mean()
    return pd.DataFrame({'MA': ma})


def calculate_relative_strength_index(dataframe, window=14):
    delta = dataframe['Close'].diff()
    up = delta.where(delta > 0, 0)
    down = -delta.where(delta < 0, 0)
    ema_up = up.ewm(com=window-1, adjust=False).mean()
    ema_down = down.ewm(com=window-1, adjust=False).mean()
    rs = ema_up / ema_down
    rsi = 100 - (100 / (1 + rs))
    return pd.DataFrame({'RSI': rsi})


def calculate_bollinger_bands(dataframe, window=20):
    ma = dataframe['Close'].rolling(window=window).mean()
    std = dataframe['Close'].rolling(window=window).std()
    upper_band = ma + (2 * std)
    lower_band = ma - (2 * std)
    return pd.DataFrame({'Upper Band': upper_band, 'Lower Band': lower_band})


def calculate_stochastic_oscillator(dataframe, window=14):
    low = dataframe['Low'].rolling(window=window).min()
    high = dataframe['High'].rolling(window=window).max()
    k = 100 * ((dataframe['Close'] - low) / (high - low))
    d = k.rolling(window=3).mean()
    return pd.DataFrame({'%K': k, '%D': d})


data_model = pd.DataFrame()
data_model = create_data_model(df, data_model)
# Define the number of time steps and features for the LSTM model
n_steps = 2
n_features = data_model.shape[1]

model = Sequential()
model = lstm_model(model,n_steps,n_features)
# Train the LSTM model
X_train = data_model[data_model.columns]
# y_train = data_model[['Open', 'Close']]
y_train = data_model[['Close']]
# X_train.dropna(inplace=True,axis=0)
# y_train.dropna(inplace=True,axis=0)
X = []
y = []
X, y = data_reshape(X_train, y_train, n_steps, n_features, X, y)
history = model.fit(X, y, epochs=40, batch_size=3)

# Use the LSTM model to generate trading signals
y_pred = []
y_pred = trading_strategy(model, X,y_pred)

# Define the trading rules based on the predicted values
for i in range(len(X_train)-n_steps):
    if y_pred[i] > X_train['Close'][i+n_steps]:
        trading_signals.loc[X_train.index[i+n_steps], 'signal'] = 'Buy'
        trading_signals.loc[X_train.index[i+n_steps],
                            'price'] = X_train['Close'][i+n_steps]
    elif y_pred[i] < X_train['Close'][i+n_steps]:
        trading_signals.loc[X_train.index[i+n_steps], 'signal'] = 'Sell'
        trading_signals.loc[X_train.index[i+n_steps],
                            'price'] = X_train['Close'][i+n_steps]
    else:
        trading_signals.loc[X_train.index[i+n_steps], 'signal'] = 'Hold'
        trading_signals.loc[X_train.index[i+n_steps],
                            'price'] = X_train['Close'][i+n_steps]
print(trading_signals)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/40
# 264/264 [==============================] - 15s 32ms/step - loss: 3455744.0000 - root_mean_squared_error: 1858.9633
# Epoch 2/40
# 264/264 [==============================] - 7s 28ms/step - loss: 3289957.5000 - root_mean_squared_error: 1813.8240
# Epoch 3/40
# 264/264 [==============================] - 9s 33ms/step - loss: 3008959.2500 - root_mean_squared_error: 1734.6351
# Epoch 4/40
# 264/264 [==============================] - 9s 33ms/step - loss: 2643360.2500 - root_mean_squared_error: 1625.8414
# Epoch 5/40
# 264/264 [==============================] - 7s 28ms/step - loss: 2293342.2500 - root_mean_squared_error: 1514.3785
# Epoch 6/40
# 264/264 [==============================] - 9s 33ms/step - loss: 1929643.1250 - root_mean_squared_error: 1389.1160
# Epoch 7/40
# ...

# %%
demo=0
for row in trading_signals.iterrows():
    # print(row[1]['signal'],row[1]['price'])
    if (row[1]['signal']=='Buy'):
      demo-=row[1]['price']
      print(demo)
    elif(row[1]['signal']=='Sell'):
      demo+=row[1]['price']
      # print(demo)
    # else:
    #   continue;
print(demo)
# Out:
# -231.5
# -460.9499969482422
# -681.8499908447266
# -907.2999877929688
# -1143.5499877929688
# -1380.0499877929688
# -1619.5499877929688
# -1864.0499877929688
# -2109.3499908447266
# -2359.0499877929688
# -2610.499984741211
# -2866.6499786376953
# -3119.1499786376953
# -3368.5999755859375
# -3622.5999755859375
# -3881.249969482422
# -4128.499969482422
# -4374.949966430664
# -4617.749969482422
# -4851.899963378906
# -5070.549957275391
# -5289.149963378906
# -5514.899963378906
# -5735.999969482422
# -5957.749969482422
# -6172.499969482422
# -6372.199966430664
# -6567.949966430664
# -6730.099960327148
# -6878.849960327148
# -7013.549957275391
# -7146.949951171875
# -7277.149948120117
# -7406.049942016602
# -7543.749938964844
# -7664.649940490723
# -7794.999946594238
# -7927.299949645996
# -8067.549949645996
# -8195.549949645996
# -8324.249946594238
# -8461.849952697754
# -8595.799949645996
# -8724.849952697754
# -8862.999946594238
# -9001.099952697754
# -8135.149971008301
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Load time series data


# Plot ACF and PACF with lag = 5
for col in data_model.columns:
  fig, ax = plt.subplots(figsize=(12, 6))
  plot_acf(data_model[col], lags=5, ax=ax)
  plot_pacf(data_model[col], lags=5, ax=ax)
  # plt.xlable(col)
  plt.show()

# %%
import pandas as pd

df = pd.DataFrame({'col1': [1, 2, 3], 'col2': ['a', 'b', 'c']})

# for index, row in enumerate(df.iterrows()):
#     print(index, row[0], row[1]['col1'], row[1]['col2'])
for row in df.iterrows():
    print(row[0], row[1]['col1'], row[1]['col2'])
# Out:
# 0 1 a
# 1 2 b
# 2 3 c

# %%
pip install Tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.9/585.9 MB 1.5 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(12,7))
plt.plot(y)
plt.plot(y_pred)
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
